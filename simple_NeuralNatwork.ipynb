# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-Lahad/Simple_NuralNatwork/blob/main/simple_NeuralNatwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
#Create the Model Class that inherit the nn.Module
class Model(nn.Module):
    def __init__(self, in_features=4, h1=8, h2=9, out_features=3):
        super().__init__(); #instantiate nn.Module
        self.fc1 = nn.Linear(in_features, h1)
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)

    def forword(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

# %%
#pick a manual seed for rendamization
torch.manual_seed(41)

#Creating the instance of the module
model = Model();

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url='https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv'
my_df=pd.read_csv(url)

# %%
my_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#changing the target variable from string to integers
my_df['species'] = my_df['species'].replace('setosa',0.0)
my_df['species'] = my_df['species'].replace('versicolor',1.0)
my_df['species'] = my_df['species'].replace('virginica',2.0)
# Out:
# <ipython-input-24-03a050c58cce>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   my_df['species'] = my_df['species'].replace('versicolor',1.0)

# %%
my_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 145           6.7          3.0           5.2          2.3      2.0
# 146           6.3          2.5           5.0          1.9      2.0
# 147           6.5          3.0           5.2          2.0      2.0
# 148           6.2          3.4           5.4          2.3      2.0
# 149           5.9          3.0           5.1          1.8      2.0

# %%
#spliting the data set into X, Y and convert them into numpy array
X = my_df.drop('species', axis=1).values
y = my_df['species'].values

# %%
from sklearn.model_selection import train_test_split

# %%
#spliting the data set into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=41)

# %%
#converting the X features to float tensors
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)

# %%
#converting the Y labels to long tensors
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
#creating the loss function of the model to measure the prediction accuracy
criterion = nn.CrossEntropyLoss()

#Choosing the Adam optimizer and its learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
